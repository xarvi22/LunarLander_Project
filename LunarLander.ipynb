# %% [markdown]
# ### Importing dependencies

# %% [markdown]
# #### Importing Weights and Biases for training callback (to check out the training progress)
#
# ### Nevermind, WandB got glitched and end up showing nothing
# #### So, please, just ignore it

# %%
#import wandb
#from wandb.integration.sb3 import WandbCallback

#wandb.init(project="lunarlander_experiments")
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Appending key for api.wandb.ai to your netrc file: /Users/maksat/.netrc
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/Users/maksat/PycharmProjects/tutorials/LunarLander_Project/wandb/run-20241113_020706-y0tyhrzx</code>
# Syncing run <strong><a href='https://wandb.ai/momorov-c/lunarlander_experiments/runs/y0tyhrzx' target="_blank">laced-brook-1</a></strong> to <a href='https://wandb.ai/momorov-c/lunarlander_experiments' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/momorov-c/lunarlander_experiments' target="_blank">https://wandb.ai/momorov-c/lunarlander_experiments</a>
#  View run at <a href='https://wandb.ai/momorov-c/lunarlander_experiments/runs/y0tyhrzx' target="_blank">https://wandb.ai/momorov-c/lunarlander_experiments/runs/y0tyhrzx</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/momorov-c/lunarlander_experiments/runs/y0tyhrzx?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# Gymnasium was chosen to make environments and test out different algorithms using Stable Baselines 3.

# %%
import gymnasium as gym

from stable_baselines3 import PPO, DQN, A2C
from stable_baselines3.common.evaluation import evaluate_policy

import pandas as pd

# %%
# Making a log directory to save logs
logs = 'data/logs'

# %% [markdown]
# ### Understanding the Lunar Lander Environment and other things here
# Check out this page https://gymnasium.farama.org/environments/box2d/lunar_lander/

# %%
environment = gym.make('LunarLander-v2')

# %%
# Discrete action space means that the agent has 4 action types to choose from
# 0 - do nothing
# 1 - fire left engine
# 2 - fire main engine
# 3 - fire right engine

environment.action_space
# Out:
# Discrete(4)

# %%
# This is an observation space of the game, i.e., the state that is put into the agent
# The first two values are the (x,y) coordinates of the agent at the given moment
# The second two values are its linear velocities in x and y
# The third two values are its angle and angular velocity

# The last two values are the boolean values in the form of float numbers. 
# They represent whether the legs of the spacecraft are in contact with the ground

environment.reset()
# Out:
# (array([ 1.1892319e-03,  1.4023979e+00,  1.2044747e-01, -3.7876463e-01,
#         -1.3713022e-03, -2.7283153e-02,  0.0000000e+00,  0.0000000e+00],
#        dtype=float32),
#  {})

# %% [markdown]
# Rewards and other things, such as the conditions of the termination of the episode (one attempt of playing the game) can be found on the website mentioned above.

# %% [markdown]
# ### Important thing to note:
# If you want to check logs (they are important for the comparisons), run this cell. Then, go to localhost:6006 to open the tensorboard

# %%
# !tensorboard --logdir 'data/logs'

# %% [markdown]
# ### Comparison of the amount of training timesteps.
#
# #### First run of PPO algorithm for 1_000_000 timesteps
#
# Later on I trained a few more models using 8 cores of cpu. So, do not compare time efficiency of those 3 agents below (PPO_1mil and PPO_500000), since those were trained on 1 core of cpu

# %%
env = gym.make("LunarLander-v2") # Initializing an environment

model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=logs) #
model.learn(total_timesteps=1_000_000, callback=WandbCallback())
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to data/logs/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 86.9     |
# |    ep_rew_mean     | -142     |
# | time/              |          |
# |    fps             | 2093     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.1         |
# |    ep_rew_mean          | -139         |
# | time/                   |              |
# |    fps                  | 1602         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0074320715 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00728      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 356          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00767     |
# |    value_loss           | 1e+03        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.3        |
# |    ep_rew_mean          | -139        |
# | time/                   |             |
# |    fps                  | 1589        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009879552 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00571    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 248         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00946    |
# |    value_loss           | 832         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 94         |
# |    ep_rew_mean          | -130       |
# | time/                   |            |
# |    fps                  | 1629       |
# |    iterations           | 4          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00993217 |
# |    clip_fraction        | 0.0603     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | -0.00463   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 277        |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0075    |
# |    value_loss           | 498        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 98.5       |
# |    ep_rew_mean          | -133       |
# | time/                   |            |
# |    fps                  | 1639       |
# |    iterations           | 5          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01228742 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | -0.00383   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 272        |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00748   |
# |    value_loss           | 515        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | -131        |
# | time/                   |             |
# |    fps                  | 1653        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008947546 |
# |    clip_fraction        | 0.0323      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.00222    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 290         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00494    |
# |    value_loss           | 653         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | -124        |
# | time/                   |             |
# |    fps                  | 1658        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015085478 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.00352    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 186         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00614    |
# |    value_loss           | 551         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 119         |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 1658        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007902843 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -0.000268   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 161         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0065     |
# |    value_loss           | 391         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 1659        |
# |    iterations           | 9           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009142187 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -0.000312   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 132         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00693    |
# |    value_loss           | 286         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 133          |
# |    ep_rew_mean          | -106         |
# | time/                   |              |
# |    fps                  | 1650         |
# |    iterations           | 10           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0066119353 |
# |    clip_fraction        | 0.0365       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | -0.0182      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 192          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00679     |
# |    value_loss           | 405          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 1658        |
# |    iterations           | 11          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005153441 |
# |    clip_fraction        | 0.0322      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | -7.5e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 126         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00679    |
# |    value_loss           | 347         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | -96.5       |
# | time/                   |             |
# |    fps                  | 1660        |
# |    iterations           | 12          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.004197064 |
# |    clip_fraction        | 0.000293    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.00465     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.9        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00261    |
# |    value_loss           | 187         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | -89.6       |
# | time/                   |             |
# |    fps                  | 1637        |
# |    iterations           | 13          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.004586876 |
# |    clip_fraction        | 0.0103      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -0.0163     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 101         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00647    |
# |    value_loss           | 235         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | -82.7        |
# | time/                   |              |
# |    fps                  | 1648         |
# |    iterations           | 14           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0028388775 |
# |    clip_fraction        | 0.00332      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.0647       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 99.5         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0029      |
# |    value_loss           | 445          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | -76.8       |
# | time/                   |             |
# |    fps                  | 1657        |
# |    iterations           | 15          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010799368 |
# |    clip_fraction        | 0.036       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.9        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00742    |
# |    value_loss           | 172         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 207          |
# |    ep_rew_mean          | -77.1        |
# | time/                   |              |
# |    fps                  | 1664         |
# |    iterations           | 16           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0054864096 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.25         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 182          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00523     |
# |    value_loss           | 279          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 218         |
# |    ep_rew_mean          | -74.8       |
# | time/                   |             |
# |    fps                  | 1671        |
# |    iterations           | 17          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007754486 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.21        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 82.4        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00867    |
# |    value_loss           | 140         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 232        |
# |    ep_rew_mean          | -74.8      |
# | time/                   |            |
# |    fps                  | 1673       |
# |    iterations           | 18         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00962727 |
# |    clip_fraction        | 0.0637     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.224      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 147        |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0104    |
# |    value_loss           | 287        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 242          |
# |    ep_rew_mean          | -75.1        |
# | time/                   |              |
# |    fps                  | 1679         |
# |    iterations           | 19           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0045962604 |
# |    clip_fraction        | 0.00615      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.348        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.7         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 218          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 256          |
# |    ep_rew_mean          | -72.1        |
# | time/                   |              |
# |    fps                  | 1684         |
# |    iterations           | 20           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0027169595 |
# |    clip_fraction        | 0.00747      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.148        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 113          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00421     |
# |    value_loss           | 278          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 275         |
# |    ep_rew_mean          | -67.7       |
# | time/                   |             |
# |    fps                  | 1687        |
# |    iterations           | 21          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009724919 |
# |    clip_fraction        | 0.0433      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.607       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.9        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00742    |
# |    value_loss           | 115         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 289         |
# |    ep_rew_mean          | -66         |
# | time/                   |             |
# |    fps                  | 1691        |
# |    iterations           | 22          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009480976 |
# |    clip_fraction        | 0.0539      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.5        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0041     |
# |    value_loss           | 58.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 307         |
# |    ep_rew_mean          | -63.9       |
# | time/                   |             |
# |    fps                  | 1693        |
# |    iterations           | 23          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004781268 |
# |    clip_fraction        | 0.0203      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.7        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0048     |
# |    value_loss           | 111         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 324         |
# |    ep_rew_mean          | -61         |
# | time/                   |             |
# |    fps                  | 1677        |
# |    iterations           | 24          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008688486 |
# |    clip_fraction        | 0.0661      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.74        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00775    |
# |    value_loss           | 34.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 341          |
# |    ep_rew_mean          | -57.1        |
# | time/                   |              |
# |    fps                  | 1627         |
# |    iterations           | 25           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0064485585 |
# |    clip_fraction        | 0.0552       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.99        |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.6         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00639     |
# |    value_loss           | 40.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 353         |
# |    ep_rew_mean          | -57.6       |
# | time/                   |             |
# |    fps                  | 1623        |
# |    iterations           | 26          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010636725 |
# |    clip_fraction        | 0.0497      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.974      |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.1        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00557    |
# |    value_loss           | 33          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 370          |
# |    ep_rew_mean          | -51.3        |
# | time/                   |              |
# |    fps                  | 1613         |
# |    iterations           | 27           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0071918448 |
# |    clip_fraction        | 0.0692       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.966       |
# |    explained_variance   | 0.662        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.1         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00675     |
# |    value_loss           | 47.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 383         |
# |    ep_rew_mean          | -50.9       |
# | time/                   |             |
# |    fps                  | 1606        |
# |    iterations           | 28          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008204849 |
# |    clip_fraction        | 0.0639      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00681    |
# |    value_loss           | 99.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 405          |
# |    ep_rew_mean          | -43.9        |
# | time/                   |              |
# |    fps                  | 1602         |
# |    iterations           | 29           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0077844122 |
# |    clip_fraction        | 0.0907       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.841       |
# |    explained_variance   | 0.779        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.8         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00674     |
# |    value_loss           | 42.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 419          |
# |    ep_rew_mean          | -42.1        |
# | time/                   |              |
# |    fps                  | 1603         |
# |    iterations           | 30           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0076802783 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.934       |
# |    explained_variance   | 0.277        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 56           |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00544     |
# |    value_loss           | 160          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 436         |
# |    ep_rew_mean          | -40.1       |
# | time/                   |             |
# |    fps                  | 1606        |
# |    iterations           | 31          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008469749 |
# |    clip_fraction        | 0.0808      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.7        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00548    |
# |    value_loss           | 133         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 455          |
# |    ep_rew_mean          | -30.6        |
# | time/                   |              |
# |    fps                  | 1611         |
# |    iterations           | 32           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0083375815 |
# |    clip_fraction        | 0.0749       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.844       |
# |    explained_variance   | 0.749        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.3         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00517     |
# |    value_loss           | 40.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 455         |
# |    ep_rew_mean          | -26.8       |
# | time/                   |             |
# |    fps                  | 1615        |
# |    iterations           | 33          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008093547 |
# |    clip_fraction        | 0.036       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.5        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0044     |
# |    value_loss           | 233         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 459         |
# |    ep_rew_mean          | -22.7       |
# | time/                   |             |
# |    fps                  | 1619        |
# |    iterations           | 34          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.005008721 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 78.2        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 143         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 471          |
# |    ep_rew_mean          | -16.8        |
# | time/                   |              |
# |    fps                  | 1618         |
# |    iterations           | 35           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0059005674 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.974       |
# |    explained_variance   | 0.404        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.5         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00386     |
# |    value_loss           | 181          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 487          |
# |    ep_rew_mean          | -1.38        |
# | time/                   |              |
# |    fps                  | 1616         |
# |    iterations           | 36           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0038289058 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.939       |
# |    explained_variance   | 0.475        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.6         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 161          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 502          |
# |    ep_rew_mean          | 6.58         |
# | time/                   |              |
# |    fps                  | 1616         |
# |    iterations           | 37           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0067995517 |
# |    clip_fraction        | 0.0365       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.826       |
# |    explained_variance   | 0.508        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 82.2         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 169          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 505          |
# |    ep_rew_mean          | 17.6         |
# | time/                   |              |
# |    fps                  | 1616         |
# |    iterations           | 38           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0037922717 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.767       |
# |    explained_variance   | 0.433        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 81.1         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 210          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 517         |
# |    ep_rew_mean          | 25.9        |
# | time/                   |             |
# |    fps                  | 1616        |
# |    iterations           | 39          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004869972 |
# |    clip_fraction        | 0.0345      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.815      |
# |    explained_variance   | 0.38        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 85.4        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00331    |
# |    value_loss           | 247         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 524          |
# |    ep_rew_mean          | 35.3         |
# | time/                   |              |
# |    fps                  | 1612         |
# |    iterations           | 40           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0043668216 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.84        |
# |    explained_variance   | 0.449        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.3         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00407     |
# |    value_loss           | 156          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 525         |
# |    ep_rew_mean          | 50.3        |
# | time/                   |             |
# |    fps                  | 1613        |
# |    iterations           | 41          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.004097632 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.9        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00321    |
# |    value_loss           | 119         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 531          |
# |    ep_rew_mean          | 67.8         |
# | time/                   |              |
# |    fps                  | 1608         |
# |    iterations           | 42           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0067640473 |
# |    clip_fraction        | 0.0548       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.77        |
# |    explained_variance   | 0.363        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 89.3         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00565     |
# |    value_loss           | 217          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 543         |
# |    ep_rew_mean          | 76.8        |
# | time/                   |             |
# |    fps                  | 1605        |
# |    iterations           | 43          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004578917 |
# |    clip_fraction        | 0.0461      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26          |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0037     |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 553         |
# |    ep_rew_mean          | 87.6        |
# | time/                   |             |
# |    fps                  | 1594        |
# |    iterations           | 44          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010279113 |
# |    clip_fraction        | 0.0651      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | 0.607       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.5        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00707    |
# |    value_loss           | 102         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 549        |
# |    ep_rew_mean          | 97.6       |
# | time/                   |            |
# |    fps                  | 1589       |
# |    iterations           | 45         |
# |    time_elapsed         | 57         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00338184 |
# |    clip_fraction        | 0.0458     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.801     |
# |    explained_variance   | 0.501      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 27.6       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0019    |
# |    value_loss           | 174        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 552         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 1591        |
# |    iterations           | 46          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.004119333 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.869      |
# |    explained_variance   | 0.332       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.7        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00446    |
# |    value_loss           | 169         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 550          |
# |    ep_rew_mean          | 114          |
# | time/                   |              |
# |    fps                  | 1594         |
# |    iterations           | 47           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0036780005 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.91        |
# |    explained_variance   | 0.236        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 237          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00236     |
# |    value_loss           | 269          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 532          |
# |    ep_rew_mean          | 122          |
# | time/                   |              |
# |    fps                  | 1590         |
# |    iterations           | 48           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0035792221 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.809       |
# |    explained_variance   | 0.65         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.6         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00302     |
# |    value_loss           | 131          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 493          |
# |    ep_rew_mean          | 127          |
# | time/                   |              |
# |    fps                  | 1589         |
# |    iterations           | 49           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0052020038 |
# |    clip_fraction        | 0.0466       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.883       |
# |    explained_variance   | 0.747        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.8         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00423     |
# |    value_loss           | 116          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 479         |
# |    ep_rew_mean          | 139         |
# | time/                   |             |
# |    fps                  | 1590        |
# |    iterations           | 50          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.002881494 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 0.459       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 122         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00646    |
# |    value_loss           | 200         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 460          |
# |    ep_rew_mean          | 148          |
# | time/                   |              |
# |    fps                  | 1592         |
# |    iterations           | 51           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0053000334 |
# |    clip_fraction        | 0.0394       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.792       |
# |    explained_variance   | 0.711        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.7         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00385     |
# |    value_loss           | 68           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 454         |
# |    ep_rew_mean          | 153         |
# | time/                   |             |
# |    fps                  | 1596        |
# |    iterations           | 52          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008381072 |
# |    clip_fraction        | 0.0774      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.748      |
# |    explained_variance   | 0.763       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.1        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00573    |
# |    value_loss           | 55.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 441          |
# |    ep_rew_mean          | 153          |
# | time/                   |              |
# |    fps                  | 1599         |
# |    iterations           | 53           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0029736229 |
# |    clip_fraction        | 0.0188       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.841       |
# |    explained_variance   | 0.794        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.8         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 87.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 439          |
# |    ep_rew_mean          | 155          |
# | time/                   |              |
# |    fps                  | 1598         |
# |    iterations           | 54           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0029988582 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.832       |
# |    explained_variance   | 0.668        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.9         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00286     |
# |    value_loss           | 176          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 430         |
# |    ep_rew_mean          | 160         |
# | time/                   |             |
# |    fps                  | 1596        |
# |    iterations           | 55          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 112640      |
# ...
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 185          |
# | time/                   |              |
# |    fps                  | 1433         |
# |    iterations           | 472          |
# |    time_elapsed         | 674          |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0053692004 |
# |    clip_fraction        | 0.0818       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.504       |
# |    explained_variance   | 0.783        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.3         |
# |    n_updates            | 4710         |
# |    policy_gradient_loss | -0.00182     |
# |    value_loss           | 70.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 333          |
# |    ep_rew_mean          | 186          |
# | time/                   |              |
# |    fps                  | 1433         |
# |    iterations           | 473          |
# |    time_elapsed         | 675          |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 0.0048849946 |
# |    clip_fraction        | 0.0352       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.475       |
# |    explained_variance   | 0.724        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.1         |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 123          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 333          |
# |    ep_rew_mean          | 184          |
# | time/                   |              |
# |    fps                  | 1433         |
# |    iterations           | 474          |
# |    time_elapsed         | 677          |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0059139254 |
# |    clip_fraction        | 0.0786       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.498       |
# |    explained_variance   | 0.85         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.78         |
# |    n_updates            | 4730         |
# |    policy_gradient_loss | -0.00395     |
# |    value_loss           | 38.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 332         |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 1434        |
# |    iterations           | 475         |
# |    time_elapsed         | 678         |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.003361918 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.463      |
# |    explained_variance   | 0.769       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.17        |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | -0.00144    |
# |    value_loss           | 49.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 341          |
# |    ep_rew_mean          | 179          |
# | time/                   |              |
# |    fps                  | 1434         |
# |    iterations           | 476          |
# |    time_elapsed         | 679          |
# |    total_timesteps      | 974848       |
# | train/                  |              |
# |    approx_kl            | 0.0017742761 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.423       |
# |    explained_variance   | 0.413        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.9         |
# |    n_updates            | 4750         |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 141          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 340         |
# |    ep_rew_mean          | 180         |
# | time/                   |             |
# |    fps                  | 1435        |
# |    iterations           | 477         |
# |    time_elapsed         | 680         |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.005685191 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.81        |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | -0.00141    |
# |    value_loss           | 34.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 349        |
# |    ep_rew_mean          | 181        |
# | time/                   |            |
# |    fps                  | 1435       |
# |    iterations           | 478        |
# |    time_elapsed         | 681        |
# |    total_timesteps      | 978944     |
# | train/                  |            |
# |    approx_kl            | 0.00484725 |
# |    clip_fraction        | 0.0349     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.533     |
# |    explained_variance   | 0.664      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14.8       |
# |    n_updates            | 4770       |
# |    policy_gradient_loss | -0.00107   |
# |    value_loss           | 91.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 345         |
# |    ep_rew_mean          | 173         |
# | time/                   |             |
# |    fps                  | 1435        |
# |    iterations           | 479         |
# |    time_elapsed         | 683         |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.012401711 |
# |    clip_fraction        | 0.0989      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.512      |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.58        |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.000105   |
# |    value_loss           | 20.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 361          |
# |    ep_rew_mean          | 173          |
# | time/                   |              |
# |    fps                  | 1436         |
# |    iterations           | 480          |
# |    time_elapsed         | 684          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0075675566 |
# |    clip_fraction        | 0.0546       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | 0.714        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.6         |
# |    n_updates            | 4790         |
# |    policy_gradient_loss | -0.00239     |
# |    value_loss           | 123          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 352          |
# |    ep_rew_mean          | 182          |
# | time/                   |              |
# |    fps                  | 1436         |
# |    iterations           | 481          |
# |    time_elapsed         | 685          |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 0.0017869474 |
# |    clip_fraction        | 0.0983       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.545       |
# |    explained_variance   | 0.556        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.3         |
# |    n_updates            | 4800         |
# |    policy_gradient_loss | 0.000219     |
# |    value_loss           | 94.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 351         |
# |    ep_rew_mean          | 178         |
# | time/                   |             |
# |    fps                  | 1437        |
# |    iterations           | 482         |
# |    time_elapsed         | 686         |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.004725025 |
# |    clip_fraction        | 0.0344      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.401      |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.9        |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.00112    |
# |    value_loss           | 53.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 351         |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 1437        |
# |    iterations           | 483         |
# |    time_elapsed         | 687         |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.007525701 |
# |    clip_fraction        | 0.0628      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.558      |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.9        |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.00217    |
# |    value_loss           | 108         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 348         |
# |    ep_rew_mean          | 167         |
# | time/                   |             |
# |    fps                  | 1438        |
# |    iterations           | 484         |
# |    time_elapsed         | 689         |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.007279052 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.488      |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.1        |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.00318    |
# |    value_loss           | 139         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 354         |
# |    ep_rew_mean          | 166         |
# | time/                   |             |
# |    fps                  | 1438        |
# |    iterations           | 485         |
# |    time_elapsed         | 690         |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.004717787 |
# |    clip_fraction        | 0.0378      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.431      |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.3        |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.00174    |
# |    value_loss           | 198         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 347          |
# |    ep_rew_mean          | 163          |
# | time/                   |              |
# |    fps                  | 1438         |
# |    iterations           | 486          |
# |    time_elapsed         | 691          |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0041331025 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.55        |
# |    explained_variance   | 0.696        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.29         |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 17.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 349         |
# |    ep_rew_mean          | 164         |
# | time/                   |             |
# |    fps                  | 1438        |
# |    iterations           | 487         |
# |    time_elapsed         | 693         |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.004244179 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.513      |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.9        |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.00507    |
# |    value_loss           | 129         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 344          |
# |    ep_rew_mean          | 164          |
# | time/                   |              |
# |    fps                  | 1437         |
# |    iterations           | 488          |
# |    time_elapsed         | 695          |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0059074135 |
# |    clip_fraction        | 0.0663       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.486       |
# |    explained_variance   | 0.911        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.5         |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 62.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 342          |
# |    ep_rew_mean          | 161          |
# | time/                   |              |
# |    fps                  | 1436         |
# |    iterations           | 489          |
# |    time_elapsed         | 697          |
# |    total_timesteps      | 1001472      |
# | train/                  |              |
# |    approx_kl            | 0.0020132994 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.386       |
# |    explained_variance   | 0.831        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.1         |
# |    n_updates            | 4880         |
# |    policy_gradient_loss | -0.000499    |
# |    value_loss           | 140          |
# ------------------------------------------

# %%
model.save('models/PPO_1mil_model')

# %%
env = gym.make("LunarLander-v2", render_mode='rgb_array')

mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10, deterministic=True)

print(f"PPO - Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# PPO - Mean Reward: 161.4443761205236 +/- 103.32166450740453

# %% [markdown]
# #### Storing an evaluation of the model

# %%
results = pd.DataFrame(columns=['Algorithm', 'Mean Reward', 'Std Reward', 'Timesteps'])
name = 'PPO_1mil'

mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100, deterministic=True)
print(f"PPO - Mean Reward: {mean_reward} +/- {std_reward}")

temp_df = pd.DataFrame({
    'Algorithm' : [name],
    'Mean Reward' : [mean_reward],
    'Std Reward' : [std_reward],
    'Timesteps' : 1_000_000})

results = pd.concat([results, temp_df])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# PPO - Mean Reward: 165.55157471745926 +/- 119.14903230671855
# /var/folders/ms/mj7q028j0xxgpkb_f6mxv7sc0000gp/T/ipykernel_94494/2107417218.py:13: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, temp_df])

# %% [markdown]
# #### Running the same PPO algorithm for fewer episodees

# %%
env = gym.make("LunarLander-v2", render_mode='rgb_array')

model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=logs)
model.learn(total_timesteps=500000, callback=WandbCallback(), tb_log_name='PPO_500000')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to data/logs/PPO_500000_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89       |
# |    ep_rew_mean     | -166     |
# | time/              |          |
# |    fps             | 1595     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90.3         |
# |    ep_rew_mean          | -155         |
# | time/                   |              |
# |    fps                  | 1375         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0071888836 |
# |    clip_fraction        | 0.0642       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0114      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 790          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00738     |
# |    value_loss           | 1.55e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.3        |
# |    ep_rew_mean          | -150        |
# | time/                   |             |
# |    fps                  | 1402        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009068718 |
# |    clip_fraction        | 0.0261      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00591    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 399         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00661    |
# |    value_loss           | 742         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.1        |
# |    ep_rew_mean          | -146        |
# | time/                   |             |
# |    fps                  | 1427        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007917156 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00377     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 589         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00793    |
# |    value_loss           | 985         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.2        |
# |    ep_rew_mean          | -146        |
# | time/                   |             |
# |    fps                  | 1444        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010417396 |
# |    clip_fraction        | 0.0633      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.000332   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 294         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00795    |
# |    value_loss           | 660         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -140        |
# | time/                   |             |
# |    fps                  | 1449        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010661719 |
# |    clip_fraction        | 0.0686      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.000141   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 258         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0076     |
# |    value_loss           | 652         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 105          |
# |    ep_rew_mean          | -145         |
# | time/                   |              |
# |    fps                  | 1460         |
# |    iterations           | 7            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0080288015 |
# |    clip_fraction        | 0.0538       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.0861      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 353          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 539          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 108          |
# |    ep_rew_mean          | -144         |
# | time/                   |              |
# |    fps                  | 1468         |
# |    iterations           | 8            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0021995953 |
# |    clip_fraction        | 0.00137      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.0102      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 365          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 445          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 113          |
# |    ep_rew_mean          | -149         |
# | time/                   |              |
# |    fps                  | 1467         |
# |    iterations           | 9            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0077714836 |
# |    clip_fraction        | 0.0734       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.00515     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 295          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00375     |
# |    value_loss           | 451          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | -157        |
# | time/                   |             |
# |    fps                  | 1463        |
# |    iterations           | 10          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008132184 |
# |    clip_fraction        | 0.0411      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.024       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 169         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00734    |
# |    value_loss           | 354         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | -157        |
# | time/                   |             |
# |    fps                  | 1384        |
# |    iterations           | 11          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010329106 |
# |    clip_fraction        | 0.0501      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.0625     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 197         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.005      |
# |    value_loss           | 648         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 135         |
# |    ep_rew_mean          | -165        |
# | time/                   |             |
# |    fps                  | 1366        |
# |    iterations           | 12          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005851983 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.5        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 200         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 141          |
# |    ep_rew_mean          | -169         |
# | time/                   |              |
# |    fps                  | 1333         |
# |    iterations           | 13           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0034939528 |
# |    clip_fraction        | 0.0041       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.222        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 277          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 550          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | -167        |
# | time/                   |             |
# |    fps                  | 1239        |
# |    iterations           | 14          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004136771 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.0105      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 126         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00381    |
# |    value_loss           | 430         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 153        |
# |    ep_rew_mean          | -169       |
# | time/                   |            |
# |    fps                  | 1221       |
# |    iterations           | 15         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.00513782 |
# |    clip_fraction        | 0.025      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.24      |
# |    explained_variance   | 0.343      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 158        |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00736   |
# |    value_loss           | 482        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 152         |
# |    ep_rew_mean          | -164        |
# | time/                   |             |
# |    fps                  | 1234        |
# |    iterations           | 16          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010231288 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.0945      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 83.7        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0087     |
# |    value_loss           | 251         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -146        |
# | time/                   |             |
# |    fps                  | 1242        |
# |    iterations           | 17          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007996556 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89.1        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0056     |
# |    value_loss           | 228         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | -143        |
# | time/                   |             |
# |    fps                  | 1251        |
# |    iterations           | 18          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011240574 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 86.1        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00948    |
# |    value_loss           | 294         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 142          |
# |    ep_rew_mean          | -124         |
# | time/                   |              |
# |    fps                  | 1259         |
# |    iterations           | 19           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0062303906 |
# |    clip_fraction        | 0.0397       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.389        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 110          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0063      |
# |    value_loss           | 315          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 140          |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 1265         |
# |    iterations           | 20           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0066926763 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.0664       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 189          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00479     |
# |    value_loss           | 412          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | -100        |
# | time/                   |             |
# |    fps                  | 1198        |
# |    iterations           | 21          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.013916482 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84.5        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 288         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | -98.3       |
# | time/                   |             |
# |    fps                  | 1169        |
# |    iterations           | 22          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012741733 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.7        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00921    |
# |    value_loss           | 230         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | -88.3        |
# | time/                   |              |
# |    fps                  | 1171         |
# |    iterations           | 23           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0057418332 |
# |    clip_fraction        | 0.0444       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.324        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 176          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00497     |
# |    value_loss           | 261          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | -84.3        |
# | time/                   |              |
# |    fps                  | 1139         |
# |    iterations           | 24           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0046773376 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.366        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 122          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0054      |
# |    value_loss           | 216          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 172          |
# |    ep_rew_mean          | -81.5        |
# | time/                   |              |
# |    fps                  | 1104         |
# |    iterations           | 25           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0083037885 |
# |    clip_fraction        | 0.0973       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.593        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87.4         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00879     |
# |    value_loss           | 221          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 187          |
# |    ep_rew_mean          | -80.8        |
# | time/                   |              |
# |    fps                  | 1068         |
# |    iterations           | 26           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0047972044 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.408        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 118          |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00572     |
# |    value_loss           | 244          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | -81.4       |
# | time/                   |             |
# |    fps                  | 1041        |
# |    iterations           | 27          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007814661 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.6        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00822    |
# |    value_loss           | 85.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 213         |
# |    ep_rew_mean          | -81.7       |
# | time/                   |             |
# |    fps                  | 1030        |
# |    iterations           | 28          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010178956 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.3        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 122         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 230         |
# |    ep_rew_mean          | -78.5       |
# | time/                   |             |
# |    fps                  | 977         |
# |    iterations           | 29          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.009378831 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.671       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.5        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00624    |
# |    value_loss           | 143         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 247         |
# |    ep_rew_mean          | -75.5       |
# | time/                   |             |
# |    fps                  | 936         |
# |    iterations           | 30          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009696463 |
# |    clip_fraction        | 0.0869      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00845    |
# |    value_loss           | 43.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 264         |
# |    ep_rew_mean          | -71.3       |
# | time/                   |             |
# |    fps                  | 906         |
# |    iterations           | 31          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011848604 |
# |    clip_fraction        | 0.0864      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.1        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00687    |
# |    value_loss           | 75.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 280         |
# |    ep_rew_mean          | -72.8       |
# | time/                   |             |
# |    fps                  | 877         |
# |    iterations           | 32          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007891608 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.921      |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.8        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00544    |
# |    value_loss           | 45.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 291         |
# |    ep_rew_mean          | -71.9       |
# | time/                   |             |
# |    fps                  | 868         |
# |    iterations           | 33          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.012446449 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.6        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00982    |
# |    value_loss           | 86.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 310         |
# |    ep_rew_mean          | -67.3       |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 34          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.011460518 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.644       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.4        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 121         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 328         |
# |    ep_rew_mean          | -61.5       |
# | time/                   |             |
# |    fps                  | 819         |
# |    iterations           | 35          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.007101506 |
# |    clip_fraction        | 0.0714      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.734       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.8        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00334    |
# |    value_loss           | 61.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 344          |
# |    ep_rew_mean          | -60.2        |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 36           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0087550655 |
# |    clip_fraction        | 0.0955       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.839        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.9         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00746     |
# |    value_loss           | 31.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 352          |
# |    ep_rew_mean          | -55.5        |
# | time/                   |              |
# |    fps                  | 805          |
# |    iterations           | 37           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0074266084 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.649        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 96.9         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00436     |
# |    value_loss           | 134          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 370         |
# |    ep_rew_mean          | -55.5       |
# | time/                   |             |
# |    fps                  | 798         |
# |    iterations           | 38          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009932056 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53          |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 118         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 391        |
# |    ep_rew_mean          | -49.1      |
# | time/                   |            |
# |    fps                  | 780        |
# |    iterations           | 39         |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.01067283 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.664      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 19.1       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.00891   |
# |    value_loss           | 63.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 407         |
# |    ep_rew_mean          | -49.7       |
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 40          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011120667 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.8        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00659    |
# |    value_loss           | 78.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 424         |
# |    ep_rew_mean          | -46.7       |
# | time/                   |             |
# |    fps                  | 760         |
# |    iterations           | 41          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008884101 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.7        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 117         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 432          |
# |    ep_rew_mean          | -48.2        |
# | time/                   |              |
# |    fps                  | 751          |
# |    iterations           | 42           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0053145173 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.941       |
# |    explained_variance   | 0.551        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.1         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00358     |
# |    value_loss           | 137          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 447          |
# |    ep_rew_mean          | -45.1        |
# | time/                   |              |
# |    fps                  | 748          |
# |    iterations           | 43           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0068226373 |
# |    clip_fraction        | 0.0534       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.958       |
# |    explained_variance   | 0.591        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.7         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00405     |
# |    value_loss           | 135          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 463        |
# |    ep_rew_mean          | -44.1      |
# | time/                   |            |
# |    fps                  | 741        |
# |    iterations           | 44         |
# |    time_elapsed         | 121        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.00960538 |
# |    clip_fraction        | 0.0645     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.597      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 36.1       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00425   |
# |    value_loss           | 96.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 475          |
# |    ep_rew_mean          | -42.4        |
# | time/                   |              |
# |    fps                  | 729          |
# |    iterations           | 45           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0041581504 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.951       |
# |    explained_variance   | 0.712        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.1         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00534     |
# |    value_loss           | 120          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 492         |
# |    ep_rew_mean          | -32.5       |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 46          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.007809505 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.5        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00904    |
# |    value_loss           | 77.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 507          |
# |    ep_rew_mean          | -30          |
# | time/                   |              |
# |    fps                  | 718          |
# |    iterations           | 47           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0063604657 |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.861       |
# |    explained_variance   | 0.607        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.73         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00339     |
# |    value_loss           | 123          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 521          |
# |    ep_rew_mean          | -30.2        |
# | time/                   |              |
# |    fps                  | 710          |
# |    iterations           | 48           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0072619915 |
# |    clip_fraction        | 0.0665       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.708        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.8         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00492     |
# |    value_loss           | 57.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 536         |
# |    ep_rew_mean          | -27.8       |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 49          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.018364318 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.964      |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.1        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00494    |
# |    value_loss           | 60.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 550          |
# |    ep_rew_mean          | -29.5        |
# | time/                   |              |
# |    fps                  | 685          |
# |    iterations           | 50           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0072086817 |
# |    clip_fraction        | 0.0585       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.881       |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.22         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00281     |
# |    value_loss           | 18.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 563          |
# |    ep_rew_mean          | -26.9        |
# | time/                   |              |
# |    fps                  | 677          |
# |    iterations           | 51           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0048965476 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.937       |
# |    explained_variance   | 0.591        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.9         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00215     |
# |    value_loss           | 91.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 580         |
# |    ep_rew_mean          | -26.5       |
# | time/                   |             |
# |    fps                  | 673         |
# |    iterations           | 52          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.006146289 |
# |    clip_fraction        | 0.046       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.976      |
# |    explained_variance   | 0.742       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.28        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00254    |
# |    value_loss           | 38.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 586         |
# |    ep_rew_mean          | -27.5       |
# | time/                   |             |
# |    fps                  | 667         |
# |    iterations           | 53          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.007201043 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.885      |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.12        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00502    |
# |    value_loss           | 13.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 601          |
# |    ep_rew_mean          | -23.1        |
# | time/                   |              |
# |    fps                  | 663          |
# |    iterations           | 54           |
# |    time_elapsed         | 166          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0076050153 |
# |    clip_fraction        | 0.058        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.933       |
# |    explained_variance   | 0.686        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.18         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00265     |
# |    value_loss           | 33.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 621          |
# |    ep_rew_mean          | -19.3        |
# | time/                   |              |
# |    fps                  | 666          |
# |    iterations           | 55           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 112640       |
# ...
# | rollout/                |             |
# |    ep_len_mean          | 398         |
# |    ep_rew_mean          | 72.6        |
# | time/                   |             |
# |    fps                  | 670         |
# |    iterations           | 228         |
# |    time_elapsed         | 696         |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.008325668 |
# |    clip_fraction        | 0.0866      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.62        |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | -0.0036     |
# |    value_loss           | 58.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 397          |
# |    ep_rew_mean          | 72.2         |
# | time/                   |              |
# |    fps                  | 671          |
# |    iterations           | 229          |
# |    time_elapsed         | 698          |
# |    total_timesteps      | 468992       |
# | train/                  |              |
# |    approx_kl            | 0.0068724947 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.667       |
# |    explained_variance   | 0.794        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.4         |
# |    n_updates            | 2280         |
# |    policy_gradient_loss | -0.00374     |
# |    value_loss           | 149          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 401          |
# |    ep_rew_mean          | 74           |
# | time/                   |              |
# |    fps                  | 672          |
# |    iterations           | 230          |
# |    time_elapsed         | 700          |
# |    total_timesteps      | 471040       |
# | train/                  |              |
# |    approx_kl            | 0.0063487124 |
# |    clip_fraction        | 0.0548       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.642       |
# |    explained_variance   | 0.726        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.2         |
# |    n_updates            | 2290         |
# |    policy_gradient_loss | -0.00191     |
# |    value_loss           | 153          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 409        |
# |    ep_rew_mean          | 75.1       |
# | time/                   |            |
# |    fps                  | 672        |
# |    iterations           | 231        |
# |    time_elapsed         | 703        |
# |    total_timesteps      | 473088     |
# | train/                  |            |
# |    approx_kl            | 0.00747556 |
# |    clip_fraction        | 0.0467     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.665     |
# |    explained_variance   | 0.822      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 63.5       |
# |    n_updates            | 2300       |
# |    policy_gradient_loss | -0.00371   |
# |    value_loss           | 130        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 402         |
# |    ep_rew_mean          | 73.9        |
# | time/                   |             |
# |    fps                  | 672         |
# |    iterations           | 232         |
# |    time_elapsed         | 706         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.015742313 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.39        |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.00232    |
# |    value_loss           | 27.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 410          |
# |    ep_rew_mean          | 73.2         |
# | time/                   |              |
# |    fps                  | 672          |
# |    iterations           | 233          |
# |    time_elapsed         | 709          |
# |    total_timesteps      | 477184       |
# | train/                  |              |
# |    approx_kl            | 0.0077956803 |
# |    clip_fraction        | 0.0832       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.727       |
# |    explained_variance   | 0.684        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67.8         |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 150          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 399          |
# |    ep_rew_mean          | 75           |
# | time/                   |              |
# |    fps                  | 672          |
# |    iterations           | 234          |
# |    time_elapsed         | 712          |
# |    total_timesteps      | 479232       |
# | train/                  |              |
# |    approx_kl            | 0.0045602284 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.664       |
# |    explained_variance   | 0.68         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 152          |
# |    n_updates            | 2330         |
# |    policy_gradient_loss | -0.00203     |
# |    value_loss           | 148          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 405         |
# |    ep_rew_mean          | 78.3        |
# | time/                   |             |
# |    fps                  | 673         |
# |    iterations           | 235         |
# |    time_elapsed         | 715         |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.008618308 |
# |    clip_fraction        | 0.0344      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.585      |
# |    explained_variance   | 0.684       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.4        |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.000233   |
# |    value_loss           | 88.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 396         |
# |    ep_rew_mean          | 73.1        |
# | time/                   |             |
# |    fps                  | 673         |
# |    iterations           | 236         |
# |    time_elapsed         | 717         |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.007749915 |
# |    clip_fraction        | 0.0788      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.757      |
# |    explained_variance   | 0.717       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.2        |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.0048     |
# |    value_loss           | 126         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 391         |
# |    ep_rew_mean          | 77.2        |
# | time/                   |             |
# |    fps                  | 674         |
# |    iterations           | 237         |
# |    time_elapsed         | 719         |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.005337245 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 113         |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00162    |
# |    value_loss           | 173         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 394         |
# |    ep_rew_mean          | 87.7        |
# | time/                   |             |
# |    fps                  | 675         |
# |    iterations           | 238         |
# |    time_elapsed         | 722         |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.004663783 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.571      |
# |    explained_variance   | 0.275       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.3        |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -0.00162    |
# |    value_loss           | 105         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 391          |
# |    ep_rew_mean          | 90.8         |
# | time/                   |              |
# |    fps                  | 675          |
# |    iterations           | 239          |
# |    time_elapsed         | 724          |
# |    total_timesteps      | 489472       |
# | train/                  |              |
# |    approx_kl            | 0.0047963383 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.616       |
# |    explained_variance   | 0.549        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.9         |
# |    n_updates            | 2380         |
# |    policy_gradient_loss | -0.00289     |
# |    value_loss           | 211          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 391         |
# |    ep_rew_mean          | 90.1        |
# | time/                   |             |
# |    fps                  | 675         |
# |    iterations           | 240         |
# |    time_elapsed         | 727         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.009851229 |
# |    clip_fraction        | 0.0615      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.648      |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00392    |
# |    value_loss           | 158         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 389        |
# |    ep_rew_mean          | 87.1       |
# | time/                   |            |
# |    fps                  | 676        |
# |    iterations           | 241        |
# |    time_elapsed         | 729        |
# |    total_timesteps      | 493568     |
# | train/                  |            |
# |    approx_kl            | 0.03708022 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.675     |
# |    explained_variance   | 0.923      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 28.8       |
# |    n_updates            | 2400       |
# |    policy_gradient_loss | -0.0027    |
# |    value_loss           | 43.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 383         |
# |    ep_rew_mean          | 82.8        |
# | time/                   |             |
# |    fps                  | 676         |
# |    iterations           | 242         |
# |    time_elapsed         | 732         |
# |    total_timesteps      | 495616      |
# | train/                  |             |
# |    approx_kl            | 0.005878429 |
# |    clip_fraction        | 0.045       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | 0.798       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.3        |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | -0.0054     |
# |    value_loss           | 124         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 382          |
# |    ep_rew_mean          | 83.4         |
# | time/                   |              |
# |    fps                  | 676          |
# |    iterations           | 243          |
# |    time_elapsed         | 735          |
# |    total_timesteps      | 497664       |
# | train/                  |              |
# |    approx_kl            | 0.0031369017 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.586       |
# |    explained_variance   | 0.707        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.6         |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 167          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 367          |
# |    ep_rew_mean          | 79.2         |
# | time/                   |              |
# |    fps                  | 676          |
# |    iterations           | 244          |
# |    time_elapsed         | 739          |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0046324343 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.614       |
# |    explained_variance   | 0.75         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.9         |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 146          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 374          |
# |    ep_rew_mean          | 77.7         |
# | time/                   |              |
# |    fps                  | 675          |
# |    iterations           | 245          |
# |    time_elapsed         | 743          |
# |    total_timesteps      | 501760       |
# | train/                  |              |
# |    approx_kl            | 0.0036061958 |
# |    clip_fraction        | 0.0635       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.682       |
# |    explained_variance   | 0.863        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.28         |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | -0.0045      |
# |    value_loss           | 124          |
# ------------------------------------------

# %% [markdown]
# #### This attempt was not successful
#
# The reward went down, the episode length went up since the very beginning of the training, indicating that the agent didn't explore well.

# %%
env = gym.make("LunarLander-v2", render_mode='rgb_array')

model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=logs)
model.learn(total_timesteps=500000, callback=WandbCallback(), tb_log_name='PPO_500000_2nd')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to data/logs/PPO_500000_2nd_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.3     |
# |    ep_rew_mean     | -173     |
# | time/              |          |
# |    fps             | 2002     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.7         |
# |    ep_rew_mean          | -177         |
# | time/                   |              |
# |    fps                  | 1665         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0072733155 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00643     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 799          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00479     |
# |    value_loss           | 1.51e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.7        |
# |    ep_rew_mean          | -198        |
# | time/                   |             |
# |    fps                  | 1616        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010517356 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00214    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 401         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 1.1e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.2        |
# |    ep_rew_mean          | -190        |
# | time/                   |             |
# |    fps                  | 1581        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011878002 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.00421    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 886         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00728    |
# |    value_loss           | 1.55e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.8        |
# |    ep_rew_mean          | -178        |
# | time/                   |             |
# |    fps                  | 1563        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007831408 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.0114     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 216         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00817    |
# |    value_loss           | 674         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.8        |
# |    ep_rew_mean          | -167        |
# | time/                   |             |
# |    fps                  | 1333        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009763852 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.0701     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 434         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 502         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | -158         |
# | time/                   |              |
# |    fps                  | 1235         |
# |    iterations           | 7            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0063865557 |
# |    clip_fraction        | 0.0517       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.0151      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 255          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00324     |
# |    value_loss           | 681          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 105          |
# |    ep_rew_mean          | -139         |
# | time/                   |              |
# |    fps                  | 1252         |
# |    iterations           | 8            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0118784215 |
# |    clip_fraction        | 0.0796       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | -0.00262     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 192          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 473          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -118        |
# | time/                   |             |
# |    fps                  | 1258        |
# |    iterations           | 9           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012152608 |
# |    clip_fraction        | 0.0926      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.00105    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 183         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00849    |
# |    value_loss           | 433         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 112          |
# |    ep_rew_mean          | -113         |
# | time/                   |              |
# |    fps                  | 1275         |
# |    iterations           | 10           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0073236395 |
# |    clip_fraction        | 0.0879       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | -1.61e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 155          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00536     |
# |    value_loss           | 300          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 117        |
# |    ep_rew_mean          | -109       |
# | time/                   |            |
# |    fps                  | 1289       |
# |    iterations           | 11         |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01386345 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.21      |
# |    explained_variance   | -0.000152  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 157        |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0115    |
# |    value_loss           | 394        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 124       |
# |    ep_rew_mean          | -99.4     |
# | time/                   |           |
# |    fps                  | 1212      |
# |    iterations           | 12        |
# |    time_elapsed         | 20        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0094817 |
# |    clip_fraction        | 0.0512    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.21     |
# |    explained_variance   | -0.00116  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 91        |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -0.00797  |
# |    value_loss           | 370       |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 128          |
# |    ep_rew_mean          | -84.2        |
# | time/                   |              |
# |    fps                  | 1226         |
# |    iterations           | 13           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0068100523 |
# |    clip_fraction        | 0.00415      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -5.72e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87.3         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0008      |
# |    value_loss           | 196          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 140          |
# |    ep_rew_mean          | -81.3        |
# | time/                   |              |
# |    fps                  | 1146         |
# |    iterations           | 14           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0065515563 |
# |    clip_fraction        | 0.0216       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | -0.000212    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 135          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00169     |
# |    value_loss           | 288          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | -71.2       |
# | time/                   |             |
# |    fps                  | 1151        |
# |    iterations           | 15          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008442888 |
# |    clip_fraction        | 0.0556      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.000218    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 99.1        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00571    |
# |    value_loss           | 213         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | -66.5       |
# | time/                   |             |
# |    fps                  | 1164        |
# |    iterations           | 16          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011097087 |
# |    clip_fraction        | 0.0577      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | -0.00145    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 229         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00489    |
# |    value_loss           | 418         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 159          |
# |    ep_rew_mean          | -66.4        |
# | time/                   |              |
# |    fps                  | 1117         |
# |    iterations           | 17           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0065367054 |
# |    clip_fraction        | 0.0763       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | -2.71e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 191          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 430          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 169        |
# |    ep_rew_mean          | -59.3      |
# | time/                   |            |
# |    fps                  | 1071       |
# |    iterations           | 18         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00780413 |
# |    clip_fraction        | 0.0736     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.000173   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 202        |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0077    |
# |    value_loss           | 370        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 188         |
# |    ep_rew_mean          | -55.5       |
# | time/                   |             |
# |    fps                  | 1028        |
# |    iterations           | 19          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004168942 |
# |    clip_fraction        | 0.00645     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.0256      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.6        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00231    |
# |    value_loss           | 132         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 206         |
# |    ep_rew_mean          | -54.6       |
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 20          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.013230958 |
# |    clip_fraction        | 0.0983      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.6        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0053     |
# |    value_loss           | 90.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 220         |
# |    ep_rew_mean          | -54.7       |
# | time/                   |             |
# |    fps                  | 960         |
# |    iterations           | 21          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008772945 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.297       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.3        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00499    |
# |    value_loss           | 72.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | -55         |
# | time/                   |             |
# |    fps                  | 923         |
# |    iterations           | 22          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004068647 |
# |    clip_fraction        | 0.018       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | -0.0107     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.3        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00331    |
# |    value_loss           | 269         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 241          |
# |    ep_rew_mean          | -53.6        |
# | time/                   |              |
# |    fps                  | 911          |
# |    iterations           | 23           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0025632265 |
# |    clip_fraction        | 0.00591      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.0158       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 91.6         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.003       |
# |    value_loss           | 340          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 261          |
# |    ep_rew_mean          | -53.7        |
# | time/                   |              |
# |    fps                  | 892          |
# |    iterations           | 24           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0076543614 |
# |    clip_fraction        | 0.0425       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.312        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 103          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00643     |
# |    value_loss           | 158          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 269          |
# |    ep_rew_mean          | -58.1        |
# | time/                   |              |
# |    fps                  | 897          |
# |    iterations           | 25           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0071384325 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.941       |
# |    explained_variance   | 0.307        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 69.7         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0061      |
# |    value_loss           | 184          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 281          |
# |    ep_rew_mean          | -55.6        |
# | time/                   |              |
# |    fps                  | 872          |
# |    iterations           | 26           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0034682653 |
# |    clip_fraction        | 0.00435      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.286        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 105          |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00261     |
# |    value_loss           | 312          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | -53.4       |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 27          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004087309 |
# |    clip_fraction        | 0.0218      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.935      |
# |    explained_variance   | 0.607       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.5        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00351    |
# |    value_loss           | 119         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 308         |
# |    ep_rew_mean          | -56.1       |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 28          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011040518 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.53        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.8        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00687    |
# |    value_loss           | 80.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 328          |
# |    ep_rew_mean          | -52.7        |
# | time/                   |              |
# |    fps                  | 837          |
# |    iterations           | 29           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0043512993 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.962       |
# |    explained_variance   | 0.333        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 70.5         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 232          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 329         |
# |    ep_rew_mean          | -52         |
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 30          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.004343263 |
# |    clip_fraction        | 0.0279      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.444       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66          |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00287    |
# |    value_loss           | 110         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 342          |
# |    ep_rew_mean          | -52.4        |
# | time/                   |              |
# |    fps                  | 834          |
# |    iterations           | 31           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0058295107 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.317        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.4         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00421     |
# |    value_loss           | 223          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 354          |
# |    ep_rew_mean          | -48.2        |
# | time/                   |              |
# |    fps                  | 829          |
# |    iterations           | 32           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0052998434 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.908       |
# |    explained_variance   | 0.419        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60.2         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00244     |
# |    value_loss           | 207          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 369         |
# |    ep_rew_mean          | -46.7       |
# | time/                   |             |
# |    fps                  | 828         |
# |    iterations           | 33          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.006386376 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.8        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00444    |
# |    value_loss           | 102         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 384        |
# |    ep_rew_mean          | -44.5      |
# | time/                   |            |
# |    fps                  | 824        |
# |    iterations           | 34         |
# |    time_elapsed         | 84         |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.00905783 |
# |    clip_fraction        | 0.0504     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.947     |
# |    explained_variance   | 0.293      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 41.9       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00682   |
# |    value_loss           | 179        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 393          |
# |    ep_rew_mean          | -44.7        |
# | time/                   |              |
# |    fps                  | 829          |
# |    iterations           | 35           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0056662904 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.86        |
# |    explained_variance   | 0.318        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.3         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00444     |
# |    value_loss           | 196          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 409        |
# |    ep_rew_mean          | -44.1      |
# | time/                   |            |
# |    fps                  | 825        |
# |    iterations           | 36         |
# |    time_elapsed         | 89         |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.00931689 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.995     |
# |    explained_variance   | 0.4        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 186        |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0074    |
# |    value_loss           | 270        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 421         |
# |    ep_rew_mean          | -37.8       |
# | time/                   |             |
# |    fps                  | 821         |
# |    iterations           | 37          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.006882584 |
# |    clip_fraction        | 0.0836      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.998      |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 91.3        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00906    |
# |    value_loss           | 160         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 427          |
# |    ep_rew_mean          | -38.5        |
# | time/                   |              |
# |    fps                  | 820          |
# |    iterations           | 38           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0081407055 |
# |    clip_fraction        | 0.0924       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.986       |
# |    explained_variance   | 0.59         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 241          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00913     |
# |    value_loss           | 131          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 444         |
# |    ep_rew_mean          | -34.7       |
# | time/                   |             |
# |    fps                  | 808         |
# |    iterations           | 39          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.009157905 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.7        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00684    |
# |    value_loss           | 141         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 444         |
# |    ep_rew_mean          | -38.3       |
# | time/                   |             |
# |    fps                  | 803         |
# |    iterations           | 40          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005603834 |
# |    clip_fraction        | 0.0809      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | 0.566       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.8        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00573    |
# |    value_loss           | 108         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 452         |
# |    ep_rew_mean          | -39.6       |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 41          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.012840732 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.892      |
# |    explained_variance   | 0.356       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 110         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00508    |
# |    value_loss           | 196         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 445          |
# |    ep_rew_mean          | -39          |
# | time/                   |              |
# |    fps                  | 787          |
# |    iterations           | 42           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0072431136 |
# |    clip_fraction        | 0.0747       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.576        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.3         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00524     |
# |    value_loss           | 76.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 461          |
# |    ep_rew_mean          | -31.2        |
# | time/                   |              |
# |    fps                  | 768          |
# |    iterations           | 43           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0055815964 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.991       |
# |    explained_variance   | 0.491        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.3         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0057      |
# |    value_loss           | 163          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 463          |
# |    ep_rew_mean          | -30.2        |
# | time/                   |              |
# |    fps                  | 758          |
# |    iterations           | 44           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0061392495 |
# |    clip_fraction        | 0.0497       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.85        |
# |    explained_variance   | 0.501        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23           |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 130          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 480         |
# |    ep_rew_mean          | -25.3       |
# | time/                   |             |
# |    fps                  | 745         |
# |    iterations           | 45          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011994968 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35          |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00569    |
# |    value_loss           | 50.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 488         |
# |    ep_rew_mean          | -23.4       |
# | time/                   |             |
# |    fps                  | 732         |
# |    iterations           | 46          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.010439714 |
# |    clip_fraction        | 0.0771      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.941      |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.7        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00582    |
# |    value_loss           | 79          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 497          |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 47           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0032944935 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.957       |
# |    explained_variance   | 0.467        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 132          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000866    |
# |    value_loss           | 156          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 503         |
# |    ep_rew_mean          | -20.7       |
# | time/                   |             |
# |    fps                  | 713         |
# |    iterations           | 48          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008293217 |
# |    clip_fraction        | 0.0874      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.962      |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.1        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 93.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 509         |
# |    ep_rew_mean          | -18.4       |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 49          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.005634522 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.948      |
# |    explained_variance   | 0.642       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.8        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00362    |
# |    value_loss           | 87.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 520          |
# |    ep_rew_mean          | -15.9        |
# | time/                   |              |
# |    fps                  | 708          |
# |    iterations           | 50           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0066106305 |
# |    clip_fraction        | 0.0664       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.883       |
# |    explained_variance   | 0.613        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.8         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00394     |
# |    value_loss           | 87.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 536          |
# |    ep_rew_mean          | -11          |
# | time/                   |              |
# |    fps                  | 700          |
# |    iterations           | 51           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0072709993 |
# |    clip_fraction        | 0.0546       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.982       |
# |    explained_variance   | 0.596        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77           |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00716     |
# |    value_loss           | 122          |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 541       |
# |    ep_rew_mean          | -13.6     |
# | time/                   |           |
# |    fps                  | 697       |
# |    iterations           | 52        |
# |    time_elapsed         | 152       |
# |    total_timesteps      | 106496    |
# | train/                  |           |
# |    approx_kl            | 0.0672268 |
# |    clip_fraction        | 0.0913    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.75     |
# |    explained_variance   | 0.647     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.02      |
# |    n_updates            | 510       |
# |    policy_gradient_loss | -0.00994  |
# |    value_loss           | 63.5      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 545         |
# |    ep_rew_mean          | -14.6       |
# | time/                   |             |
# |    fps                  | 693         |
# |    iterations           | 53          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.011707024 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.5        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00704    |
# |    value_loss           | 77.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 547          |
# |    ep_rew_mean          | -14.7        |
# | time/                   |              |
# |    fps                  | 684          |
# |    iterations           | 54           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0071998066 |
# |    clip_fraction        | 0.0845       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.973       |
# |    explained_variance   | 0.705        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.7         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00483     |
# |    value_loss           | 117          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 559         |
# |    ep_rew_mean          | -13         |
# | time/                   |             |
# |    fps                  | 684         |
# |    iterations           | 55          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.004044204 |
# ...
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 367         |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 659         |
# |    iterations           | 228         |
# |    time_elapsed         | 707         |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.004369473 |
# |    clip_fraction        | 0.0573      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.535      |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.8        |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | -0.00423    |
# |    value_loss           | 37          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 366         |
# |    ep_rew_mean          | 211         |
# | time/                   |             |
# |    fps                  | 660         |
# |    iterations           | 229         |
# |    time_elapsed         | 710         |
# |    total_timesteps      | 468992      |
# | train/                  |             |
# |    approx_kl            | 0.004165939 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | -0.00167    |
# |    value_loss           | 18.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 374         |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 660         |
# |    iterations           | 230         |
# |    time_elapsed         | 713         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.005093615 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.637      |
# |    explained_variance   | 0.703       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.1        |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.000872   |
# |    value_loss           | 72.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 377         |
# |    ep_rew_mean          | 212         |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 231         |
# |    time_elapsed         | 715         |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.035075843 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.606      |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.26        |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.00263    |
# |    value_loss           | 55          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 383         |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 232         |
# |    time_elapsed         | 717         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.004126559 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.621      |
# |    explained_variance   | 0.789       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.57        |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.00207    |
# |    value_loss           | 57.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 384         |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 662         |
# |    iterations           | 233         |
# |    time_elapsed         | 720         |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.010792502 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.649      |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | 0.000149    |
# |    value_loss           | 19.7        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 384       |
# |    ep_rew_mean          | 213       |
# | time/                   |           |
# |    fps                  | 663       |
# |    iterations           | 234       |
# |    time_elapsed         | 722       |
# |    total_timesteps      | 479232    |
# | train/                  |           |
# |    approx_kl            | 0.0046125 |
# |    clip_fraction        | 0.0495    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.578    |
# |    explained_variance   | 0.77      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 21.5      |
# |    n_updates            | 2330      |
# |    policy_gradient_loss | -0.00246  |
# |    value_loss           | 36.8      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 379         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 664         |
# |    iterations           | 235         |
# |    time_elapsed         | 724         |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.007291437 |
# |    clip_fraction        | 0.0686      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.605      |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.63        |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.00132    |
# |    value_loss           | 22.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 379          |
# |    ep_rew_mean          | 218          |
# | time/                   |              |
# |    fps                  | 664          |
# |    iterations           | 236          |
# |    time_elapsed         | 727          |
# |    total_timesteps      | 483328       |
# | train/                  |              |
# |    approx_kl            | 0.0040678596 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.558       |
# |    explained_variance   | 0.892        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.4         |
# |    n_updates            | 2350         |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 22.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 393          |
# |    ep_rew_mean          | 217          |
# | time/                   |              |
# |    fps                  | 664          |
# |    iterations           | 237          |
# |    time_elapsed         | 730          |
# |    total_timesteps      | 485376       |
# | train/                  |              |
# |    approx_kl            | 0.0047347844 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.608       |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.8         |
# |    n_updates            | 2360         |
# |    policy_gradient_loss | 2.26e-05     |
# |    value_loss           | 15.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 394         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 664         |
# |    iterations           | 238         |
# |    time_elapsed         | 733         |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.010460566 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.701       |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | 0.000273    |
# |    value_loss           | 7.21        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 401          |
# |    ep_rew_mean          | 216          |
# | time/                   |              |
# |    fps                  | 664          |
# |    iterations           | 239          |
# |    time_elapsed         | 736          |
# |    total_timesteps      | 489472       |
# | train/                  |              |
# |    approx_kl            | 0.0045843087 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.555       |
# |    explained_variance   | 0.733        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.6         |
# |    n_updates            | 2380         |
# |    policy_gradient_loss | -0.00233     |
# |    value_loss           | 45.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 408         |
# |    ep_rew_mean          | 214         |
# | time/                   |             |
# |    fps                  | 665         |
# |    iterations           | 240         |
# |    time_elapsed         | 738         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.009380544 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12        |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.0018     |
# |    value_loss           | 5.48        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 412         |
# |    ep_rew_mean          | 213         |
# | time/                   |             |
# |    fps                  | 665         |
# |    iterations           | 241         |
# |    time_elapsed         | 741         |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.003933692 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.51       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.56        |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.00109    |
# |    value_loss           | 16.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 415         |
# |    ep_rew_mean          | 216         |
# | time/                   |             |
# |    fps                  | 666         |
# |    iterations           | 242         |
# |    time_elapsed         | 743         |
# |    total_timesteps      | 495616      |
# | train/                  |             |
# |    approx_kl            | 0.009231028 |
# |    clip_fraction        | 0.0771      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.03        |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 9.2         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 407        |
# |    ep_rew_mean          | 223        |
# | time/                   |            |
# |    fps                  | 667        |
# |    iterations           | 243        |
# |    time_elapsed         | 746        |
# |    total_timesteps      | 497664     |
# | train/                  |            |
# |    approx_kl            | 0.00281482 |
# |    clip_fraction        | 0.0268     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.586     |
# |    explained_variance   | 0.939      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.75       |
# |    n_updates            | 2420       |
# |    policy_gradient_loss | -0.00154   |
# |    value_loss           | 16.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 404          |
# |    ep_rew_mean          | 226          |
# | time/                   |              |
# |    fps                  | 667          |
# |    iterations           | 244          |
# |    time_elapsed         | 749          |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0057275267 |
# |    clip_fraction        | 0.073        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.572       |
# |    explained_variance   | 0.851        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.53         |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | -0.00369     |
# |    value_loss           | 39.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 397          |
# |    ep_rew_mean          | 228          |
# | time/                   |              |
# |    fps                  | 667          |
# |    iterations           | 245          |
# |    time_elapsed         | 751          |
# |    total_timesteps      | 501760       |
# | train/                  |              |
# |    approx_kl            | 0.0032089157 |
# |    clip_fraction        | 0.0358       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.612       |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.76         |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | -0.000897    |
# |    value_loss           | 15           |
# ------------------------------------------

# %%
model.save('models/PPO_500000_2nd_attempt')

# %%
env = gym.make("LunarLander-v2", render_mode='rgb_array')

mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10, deterministic=True)

print(f"PPO - Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# PPO - Mean Reward: 208.16804920145992 +/- 62.315576606305754

# %%
name = 'PPO_500k'

mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100, deterministic=True)
print(f"PPO - Mean Reward: {mean_reward} +/- {std_reward}")

temp_df = pd.DataFrame({
    'Algorithm': [name],
    'Mean Reward': [mean_reward],
    'Std Reward': [std_reward],
    'Timesteps': 500000})

results = pd.concat([results, temp_df])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# PPO - Mean Reward: 188.9723823407851 +/- 101.74879156113954

# %%
results
# Out:
#   Algorithm  Mean Reward  Std Reward Timesteps
# 0  PPO_1mil   165.551575  119.149032   1000000
# 0  PPO_500k   188.972382  101.748792    500000

# %% [markdown]
# #### Testing DQN algorithm
# exploration_fraction indicates what fraction of the training episodes model has to explore, slowly decaying gamma

# %%
env = gym.make('LunarLander-v2', render_mode='rgb_array')

model = DQN('MlpPolicy', env, exploration_fraction=0.5, verbose=1, tensorboard_log=logs)
model.learn(total_timesteps=1_000_000, callback=WandbCallback(), tb_log_name='DQN_1mil')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to data/logs/DQN_1mil_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -146     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1260     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 369      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75     |
# |    n_updates        | 67       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 932      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 752      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.84     |
# |    n_updates        | 162      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1056     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1141     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27     |
# |    n_updates        | 260      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1120     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1491     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.8      |
# |    n_updates        | 347      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | -226     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1192     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1896     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.13     |
# |    n_updates        | 448      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.7     |
# |    ep_rew_mean      | -225     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1225     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2297     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.38     |
# |    n_updates        | 549      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -215     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1218     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2596     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.619    |
# |    n_updates        | 623      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1212     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2987     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.12     |
# |    n_updates        | 721      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1173     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3349     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.86     |
# |    n_updates        | 812      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1183     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3710     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.95     |
# |    n_updates        | 902      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1191     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4027     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.55     |
# |    n_updates        | 981      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -197     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1204     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4361     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.848    |
# |    n_updates        | 1065     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1222     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4777     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.468    |
# |    n_updates        | 1169     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1238     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5091     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.92     |
# |    n_updates        | 1247     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1245     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5473     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.318    |
# |    n_updates        | 1343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1264     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5859     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.503    |
# |    n_updates        | 1439     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1267     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6202     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.23     |
# |    n_updates        | 1525     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1278     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6534     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.23     |
# |    n_updates        | 1608     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1274     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6874     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.55     |
# |    n_updates        | 1693     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1284     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7296     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76     |
# |    n_updates        | 1798     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1297     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7727     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.35     |
# |    n_updates        | 1906     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1308     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8103     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.71     |
# |    n_updates        | 2000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1319     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8498     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01     |
# |    n_updates        | 2099     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1330     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8895     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.56     |
# |    n_updates        | 2198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1340     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9261     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.71     |
# |    n_updates        | 2290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1348     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 9610     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.44     |
# |    n_updates        | 2377     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1356     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 9950     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.555    |
# |    n_updates        | 2462     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1361     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 10279    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.96     |
# |    n_updates        | 2544     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1363     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 10644    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.01     |
# |    n_updates        | 2635     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1364     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 10988    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.31     |
# |    n_updates        | 2721     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1371     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 11294    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.961    |
# |    n_updates        | 2798     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1377     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 11682    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.35     |
# |    n_updates        | 2895     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1384     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 12037    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.87     |
# |    n_updates        | 2984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1388     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 12381    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.73     |
# |    n_updates        | 3070     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1388     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 12733    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.59     |
# |    n_updates        | 3158     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1379     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 13091    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6        |
# |    n_updates        | 3247     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1366     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 13461    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3        |
# |    n_updates        | 3340     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1350     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 13813    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.515    |
# |    n_updates        | 3428     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1323     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 14243    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.773    |
# |    n_updates        | 3535     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1308     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 14612    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.759    |
# |    n_updates        | 3627     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1298     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 14946    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.395    |
# |    n_updates        | 3711     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1289     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 15347    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.685    |
# |    n_updates        | 3811     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1282     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 15710    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.434    |
# |    n_updates        | 3902     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1277     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 15983    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.821    |
# |    n_updates        | 3970     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1275     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 16301    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.94     |
# |    n_updates        | 4050     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.3     |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1276     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 16660    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.425    |
# |    n_updates        | 4139     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1282     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 17105    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.326    |
# |    n_updates        | 4251     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1287     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 17569    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.379    |
# |    n_updates        | 4367     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1293     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 18010    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.374    |
# |    n_updates        | 4477     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1298     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 18377    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.507    |
# |    n_updates        | 4569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1304     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 18743    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.321    |
# |    n_updates        | 4660     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1308     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 19091    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.2      |
# |    n_updates        | 4747     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1312     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 19418    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.618    |
# |    n_updates        | 4829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1317     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 19851    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.53     |
# |    n_updates        | 4937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1321     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 20196    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.45     |
# |    n_updates        | 5023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1325     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 20610    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.895    |
# |    n_updates        | 5127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1329     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 20961    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.36     |
# |    n_updates        | 5215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1332     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 21299    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.904    |
# |    n_updates        | 5299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1336     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 21681    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.627    |
# |    n_updates        | 5395     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1341     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 22118    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.847    |
# |    n_updates        | 5504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1344     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 22490    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.824    |
# |    n_updates        | 5597     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1348     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 22796    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.561    |
# |    n_updates        | 5673     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1351     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 23129    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14     |
# |    n_updates        | 5757     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1353     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 23423    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.737    |
# |    n_updates        | 5830     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1356     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 23784    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.612    |
# |    n_updates        | 5920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1357     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 24130    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.345    |
# |    n_updates        | 6007     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1360     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 24486    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.734    |
# |    n_updates        | 6096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1364     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 24880    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.13     |
# |    n_updates        | 6194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1367     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 25264    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.422    |
# |    n_updates        | 6290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1369     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 25635    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.42     |
# |    n_updates        | 6383     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1372     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 26027    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.508    |
# |    n_updates        | 6481     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.6     |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1372     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 26567    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.81     |
# |    n_updates        | 6616     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1375     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 26982    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.548    |
# |    n_updates        | 6720     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1377     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 27314    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.51     |
# |    n_updates        | 6803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -156     |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1379     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 27693    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.977    |
# |    n_updates        | 6898     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -155     |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1382     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 28012    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.757    |
# |    n_updates        | 6977     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | -158     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1384     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 28451    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.13     |
# |    n_updates        | 7087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.5     |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1386     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 28866    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.53     |
# |    n_updates        | 7191     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.3     |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1390     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 29283    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.266    |
# |    n_updates        | 7295     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.6     |
# |    ep_rew_mean      | -155     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1392     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 29653    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.63     |
# |    n_updates        | 7388     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1395     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 30121    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.48     |
# |    n_updates        | 7505     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96       |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1397     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 30563    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.91     |
# |    n_updates        | 7615     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.1     |
# |    ep_rew_mean      | -152     |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1399     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 30908    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.68     |
# |    n_updates        | 7701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.7     |
# |    ep_rew_mean      | -155     |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1401     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 31252    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.2      |
# |    n_updates        | 7787     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | -154     |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1403     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 31605    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.663    |
# |    n_updates        | 7876     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | -152     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1406     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 32045    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.03     |
# |    n_updates        | 7986     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.5     |
# |    ep_rew_mean      | -152     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1408     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 32446    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.25     |
# |    n_updates        | 8086     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.8     |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1409     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 32806    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.33     |
# |    n_updates        | 8176     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.6     |
# |    ep_rew_mean      | -157     |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1398     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 33281    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.983    |
# |    n_updates        | 8295     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.6     |
# |    ep_rew_mean      | -156     |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1393     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 33743    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.567    |
# |    n_updates        | 8410     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1391     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 34128    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.556    |
# |    n_updates        | 8506     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    time_elapsed     | 1814     |
# |    total_timesteps  | 879647   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.45     |
# |    n_updates        | 219886   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 957      |
# |    ep_rew_mean      | -49.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2980     |
# |    fps              | 484      |
# |    time_elapsed     | 1823     |
# |    total_timesteps  | 883643   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.372    |
# |    n_updates        | 220885   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 957      |
# |    ep_rew_mean      | -53.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2984     |
# |    fps              | 484      |
# |    time_elapsed     | 1832     |
# |    total_timesteps  | 887331   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.683    |
# |    n_updates        | 221807   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 957      |
# |    ep_rew_mean      | -53.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2988     |
# |    fps              | 483      |
# |    time_elapsed     | 1842     |
# |    total_timesteps  | 891331   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.521    |
# |    n_updates        | 222807   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 957      |
# |    ep_rew_mean      | -53.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2992     |
# |    fps              | 483      |
# |    time_elapsed     | 1851     |
# |    total_timesteps  | 895331   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.743    |
# |    n_updates        | 223807   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 948      |
# |    ep_rew_mean      | -54      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2996     |
# |    fps              | 483      |
# |    time_elapsed     | 1858     |
# |    total_timesteps  | 898435   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.92     |
# |    n_updates        | 224583   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 953      |
# |    ep_rew_mean      | -55.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3000     |
# |    fps              | 482      |
# |    time_elapsed     | 1869     |
# |    total_timesteps  | 902435   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.49     |
# |    n_updates        | 225583   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 953      |
# |    ep_rew_mean      | -56.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3004     |
# |    fps              | 482      |
# |    time_elapsed     | 1878     |
# |    total_timesteps  | 906435   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.554    |
# |    n_updates        | 226583   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 953      |
# |    ep_rew_mean      | -57.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3008     |
# |    fps              | 482      |
# |    time_elapsed     | 1886     |
# |    total_timesteps  | 910435   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.605    |
# |    n_updates        | 227583   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 957      |
# |    ep_rew_mean      | -58.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3012     |
# |    fps              | 482      |
# |    time_elapsed     | 1896     |
# |    total_timesteps  | 914435   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.65     |
# |    n_updates        | 228583   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 960      |
# |    ep_rew_mean      | -57.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3016     |
# |    fps              | 481      |
# |    time_elapsed     | 1906     |
# |    total_timesteps  | 918435   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.505    |
# |    n_updates        | 229583   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 962      |
# |    ep_rew_mean      | -54.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3020     |
# |    fps              | 481      |
# |    time_elapsed     | 1916     |
# |    total_timesteps  | 922435   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.533    |
# |    n_updates        | 230583   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 968      |
# |    ep_rew_mean      | -53.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3024     |
# |    fps              | 481      |
# |    time_elapsed     | 1924     |
# |    total_timesteps  | 926435   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.753    |
# |    n_updates        | 231583   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 967      |
# |    ep_rew_mean      | -51.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3028     |
# |    fps              | 481      |
# |    time_elapsed     | 1932     |
# |    total_timesteps  | 930064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.586    |
# |    n_updates        | 232490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 973      |
# |    ep_rew_mean      | -50.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3032     |
# |    fps              | 480      |
# |    time_elapsed     | 1942     |
# |    total_timesteps  | 934064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.467    |
# |    n_updates        | 233490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 973      |
# |    ep_rew_mean      | -50.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3036     |
# |    fps              | 480      |
# |    time_elapsed     | 1953     |
# |    total_timesteps  | 938064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.51     |
# |    n_updates        | 234490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 975      |
# |    ep_rew_mean      | -51.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3040     |
# |    fps              | 479      |
# |    time_elapsed     | 1963     |
# |    total_timesteps  | 942064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.17     |
# |    n_updates        | 235490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 979      |
# |    ep_rew_mean      | -49.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3044     |
# |    fps              | 480      |
# |    time_elapsed     | 1970     |
# |    total_timesteps  | 946064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.68     |
# |    n_updates        | 236490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 983      |
# |    ep_rew_mean      | -49.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3048     |
# |    fps              | 479      |
# |    time_elapsed     | 1980     |
# |    total_timesteps  | 950064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.18     |
# |    n_updates        | 237490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 983      |
# |    ep_rew_mean      | -49.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3052     |
# |    fps              | 478      |
# |    time_elapsed     | 1991     |
# |    total_timesteps  | 954064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.669    |
# |    n_updates        | 238490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 983      |
# |    ep_rew_mean      | -47.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3056     |
# |    fps              | 478      |
# |    time_elapsed     | 2002     |
# |    total_timesteps  | 958064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.508    |
# |    n_updates        | 239490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 983      |
# |    ep_rew_mean      | -47.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3060     |
# |    fps              | 477      |
# |    time_elapsed     | 2013     |
# |    total_timesteps  | 962064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.404    |
# |    n_updates        | 240490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 983      |
# |    ep_rew_mean      | -45.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3064     |
# |    fps              | 477      |
# |    time_elapsed     | 2023     |
# |    total_timesteps  | 966064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.7      |
# |    n_updates        | 241490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 984      |
# |    ep_rew_mean      | -46.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3068     |
# |    fps              | 477      |
# |    time_elapsed     | 2032     |
# |    total_timesteps  | 970064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.09     |
# |    n_updates        | 242490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 984      |
# |    ep_rew_mean      | -44.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3072     |
# |    fps              | 476      |
# |    time_elapsed     | 2042     |
# |    total_timesteps  | 974064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.6      |
# |    n_updates        | 243490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 984      |
# |    ep_rew_mean      | -44      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3076     |
# |    fps              | 476      |
# |    time_elapsed     | 2053     |
# |    total_timesteps  | 978064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.575    |
# |    n_updates        | 244490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 984      |
# |    ep_rew_mean      | -44.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3080     |
# |    fps              | 476      |
# |    time_elapsed     | 2062     |
# |    total_timesteps  | 982064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.96     |
# |    n_updates        | 245490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 987      |
# |    ep_rew_mean      | -42.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3084     |
# |    fps              | 475      |
# |    time_elapsed     | 2072     |
# |    total_timesteps  | 986064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.611    |
# |    n_updates        | 246490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 987      |
# |    ep_rew_mean      | -42.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3088     |
# |    fps              | 475      |
# |    time_elapsed     | 2083     |
# |    total_timesteps  | 990064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.545    |
# |    n_updates        | 247490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 987      |
# |    ep_rew_mean      | -41.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3092     |
# |    fps              | 474      |
# |    time_elapsed     | 2093     |
# |    total_timesteps  | 994064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.402    |
# |    n_updates        | 248490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 996      |
# |    ep_rew_mean      | -40.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3096     |
# |    fps              | 474      |
# |    time_elapsed     | 2103     |
# |    total_timesteps  | 998064   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.729    |
# |    n_updates        | 249490   |
# ----------------------------------

# %% [markdown]
# #### This attempt of training was not successful too. It didn't explore enough.
# I didn't like DQN's, they don't perform well

# %%
model.save('models/DQN_1mil_model')

# %%
name = 'DQN_1mil'

mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100, deterministic=True)
print(f"PPO - Mean Reward: {mean_reward} +/- {std_reward}")

temp_df = pd.DataFrame({
    'Algorithm': [name],
    'Mean Reward': [mean_reward],
    'Std Reward': [std_reward],
    'Timesteps': 500000})

results = pd.concat([results, temp_df])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 3
#       1 name = 'DQN_1mil'
# ----> 3 mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100, deterministic=True)
#       4 print(f"PPO - Mean Reward: {mean_reward} +/- {std_reward}")
#       6 temp_df = pd.DataFrame({
#       7     'Algorithm': [name],
#       8     'Mean Reward': [mean_reward],
#       9     'Std Reward': [std_reward],
#      10     'Timesteps': 500000})
#
# File /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:88, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      86 episode_starts = np.ones((env.num_envs,), dtype=bool)
#      87 while (episode_counts < episode_count_targets).any():
# ---> 88     actions, states = model.predict(
#      89         observations,  # type: ignore[arg-type]
#      90         state=states,
#      91         episode_start=episode_starts,
#      92         deterministic=deterministic,
#      93     )
#      94     new_observations, rewards, dones, infos = env.step(actions)
#      95     current_rewards += rewards
#
# File /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/dqn/dqn.py:255, in DQN.predict(self, observation, state, episode_start, deterministic)
#     253         action = np.array(self.action_space.sample())
#     254 else:
# --> 255     action, state = self.policy.predict(observation, state, episode_start, deterministic)
#     256 return action, state
#
# File /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/policies.py:368, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
# --> 368     actions = self._predict(obs_tensor, deterministic=deterministic)
#     369 # Convert to numpy, and reshape to the original action shape
#     370 actions = actions.cpu().numpy().reshape((-1, *self.action_space.shape))  # type: ignore[misc, assignment]
#
# File /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/dqn/policies.py:184, in DQNPolicy._predict(self, obs, deterministic)
#     183 def _predict(self, obs: PyTorchObs, deterministic: bool = True) -> th.Tensor:
# --> 184     return self.q_net._predict(obs, deterministic=deterministic)
#
# File /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/dqn/policies.py:69, in QNetwork._predict(self, observation, deterministic)
#      68 def _predict(self, observation: PyTorchObs, deterministic: bool = True) -> th.Tensor:
# ---> 69     q_values = self(observation)
#      70     # Greedy action
#      71     action = q_values.argmax(dim=1).reshape(-1)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/dqn/policies.py:66, in QNetwork.forward(self, obs)
#      59 def forward(self, obs: PyTorchObs) -> th.Tensor:
#      60     """
#      61     Predict the q-values.
#      62
#      63     :param obs: Observation
#      64     :return: The estimated Q-Value for each action.
#      65     """
# ---> 66     return self.q_net(self.extract_features(obs, self.features_extractor))
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Testing A2C algorithm

# %%
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import SubprocVecEnv

if __name__=="__main__":
    env = make_vec_env("LunarLander-v2", n_envs=8, vec_env_cls=SubprocVecEnv)
    model = A2C("MlpPolicy", env, device="cpu", tensorboard_log=logs)
    model.learn(total_timesteps=1000000, callback=WandbCallback(), tb_log_name='A2C_1mil')

# %% [markdown]
# ### Very unstable run
#
# The reward value dropped very quickly because agent reduced the episode length but didn't adjust itself to it.

# %%
model.save('models/A2C_1mil_model')

# %% [markdown]
# Trying to lower the learning rate, since the agent is overreacting to the changes (a lot of fluctuations on the episode reward graph). Default learning rate in SB3 is 0.0007

# %%
env = make_vec_env("LunarLander-v2", n_envs=8, vec_env_cls=SubprocVecEnv)
model = A2C("MlpPolicy", env, learning_rate=0.0001, device="cpu", tensorboard_log=logs)
model.learn(total_timesteps=1000000, callback=WandbCallback(), tb_log_name='A2C_1mil_adjusted')

# %%
model.save('models/A2C_1mil_adjusted')

# %% [markdown]
# Again, the mean score is -36. Trying higher learning rate

# %%
env = make_vec_env("LunarLander-v2", n_envs=8, vec_env_cls=SubprocVecEnv)
model = A2C("MlpPolicy", env, learning_rate=0.00045, device="cpu", tensorboard_log=logs)
model.learn(total_timesteps=1000000, callback=WandbCallback(), tb_log_name='A2C_1mil_adjusted2')

# %%
model.save('models/A2C_1mil_adjusted2')

# %% [markdown]
# ### Trying different learning rates to see the performance of the agents

# %%
# This command shows the information about the function. 
# I used it to look up default values of the parameters.

PPO??

# %% [markdown]
# Trying to increase a learning rate 10 times

# %%
# default learning rate of PPO is 0.0003

env = make_vec_env("LunarLander-v2", n_envs=8, vec_env_cls=SubprocVecEnv)
model = PPO("MlpPolicy", env, learning_rate=0.003, device="cpu", tensorboard_log=logs)
model.learn(total_timesteps=1000000, callback=WandbCallback(), tb_log_name='PPO_10times_LR')

# %%
model.save('models/PPO_10times_LR')

# %%
env = gym.make("LunarLander-v2", render_mode='rgb_array')

mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100, deterministic=True)
print(f"PPO - Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# PPO - Mean Reward: 210.33921440428344 +/- 59.028505439107256

# %% [markdown]
# Trying out learning rate which is 10 times lower than default

# %%
# default learning rate of PPO is 0.0003

env = make_vec_env("LunarLander-v2", n_envs=8, vec_env_cls=SubprocVecEnv)
model = PPO("MlpPolicy", env, learning_rate=0.00003, device="cpu", tensorboard_log=logs)
model.learn(total_timesteps=1000000, callback=WandbCallback(), tb_log_name='PPO_0.1times_LR')

# %%
model.save('models/PPO_0_1times_LR')

# %% [markdown]
# Default learning rate

# %%
model = PPO('MlpPolicy', env, tensorboard_log=logs)
model.learn(total_timesteps=1000000, callback=WandbCallback(), tb_log_name='PPO_default_LR')

# %%
model.save('models/PPO_default_LR')

# %%
# Run this cell to visualize the agent's gameplay locally
model.load('models/PPO_default_LR')
env = gym.make("LunarLander-v2", render_mode='human')

mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10, deterministic=True)
print(f"PPO - Mean Reward: {mean_reward} +/- {std_reward}")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# PPO - Mean Reward: 193.9048228531026 +/- 83.52647337219422

# %% [markdown]
# ### To visualize any model locally:

# %%
name = 'models/put the name of the model here'
model = model.load(name)

env = gym.make('LunarLander-v2', render_mode='human')

episodes = 5 # Nums of episodes

for episode in range(episodes):
    obs, info = env.reset()
    episode_reward = 0
    terminated = False
    truncated = False
    
    while not terminated and not truncated:
        action, state = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        episode_reward += reward
        env.render()
        
    print(f"Episode {episode + 1} reward: {episode_reward}")

env.close()
# Out:
# Process ForkServerProcess-258:
# Process ForkServerProcess-250:
# Process ForkServerProcess-251:
# Process ForkServerProcess-260:
# Process ForkServerProcess-249:
# Process ForkServerProcess-254:
# Process ForkServerProcess-259:
# Process ForkServerProcess-252:
# Process ForkServerProcess-253:
# Process ForkServerProcess-241:
# Process ForkServerProcess-245:
# Process ForkServerProcess-243:
# Process ForkServerProcess-257:
# Process ForkServerProcess-263:
# Process ForkServerProcess-247:
# Process ForkServerProcess-242:
# Process ForkServerProcess-255:
# Process ForkServerProcess-204:
# Process ForkServerProcess-264:
# Process ForkServerProcess-246:
# Process ForkServerProcess-244:
# Process ForkServerProcess-203:
# Process ForkServerProcess-261:
# Process ForkServerProcess-256:
# Process ForkServerProcess-201:
# Process ForkServerProcess-208:
# Process ForkServerProcess-262:
# Process ForkServerProcess-207:
# Process ForkServerProcess-202:
# Process ForkServerProcess-206:
# Process ForkServerProcess-205:
# Process ForkServerProcess-248:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[80], line 16
#      14         obs, reward, terminated, truncated, info = env.step(action)
#      15         episode_reward += reward
# ---> 16         env.render()
#      18     print(f"Episode {episode + 1} reward: {episode_reward}")
#      20 env.close()
#
# File /opt/anaconda3/lib/python3.12/site-packages/gymnasium/core.py:471, in Wrapper.render(self)
#     469 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     470     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 471     return self.env.render()
#
# File /opt/anaconda3/lib/python3.12/site-packages/gymnasium/wrappers/order_enforcing.py:70, in OrderEnforcing.render(self, *args, **kwargs)
#      65 if not self._disable_render_order_enforcing and not self._has_reset:
#      66     raise ResetNeeded(
#      67         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      68         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      69     )
# ---> 70 return self.env.render(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/gymnasium/wrappers/env_checker.py:67, in PassiveEnvChecker.render(self, *args, **kwargs)
#      65     return env_render_passive_checker(self.env, *args, **kwargs)
#      66 else:
# ---> 67     return self.env.render(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/gymnasium/envs/box2d/lunar_lander.py:787, in LunarLander.render(self)
#     785     self.screen.blit(self.surf, (0, 0))
#     786     pygame.event.pump()
# --> 787     self.clock.tick(self.metadata["render_fps"])
#     788     pygame.display.flip()
#     789 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 32, in _worker
#     cmd, data = remote.recv()
#                 ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#           ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
